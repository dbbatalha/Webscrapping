# %%
import requests
import urllib.request
import time
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup,NavigableString

# %%
#  THIS IS THE SCRIPT FOR SCRAPE THE DATABASE FROM IBJJF FROM EUROPEAN BJJ COMPETITION

data = []
categories = []
a=[]
listz=[]


for i in range(2004,2014):      # Number of pages plus one 
    if i<= 2012:
        url='https://ibjjf.com/events/results/{}-european-jiu-jitsu-ibjjf-championship'.format(i)
        response = requests.get(url)
        soup = BeautifulSoup(response.text,"html.parser")
        result = soup.find('div', class_ = 'col-sm-12 col-md-6 athletes-result')



        for new in result.find_all('div', {'class':'col-sm-12 athletes'},'tr'):
            for athletes in new.find_all('tr'):
                data.append(athletes.find('td',class_ = 'place').text)
                data.append(athletes.find('div',class_ = 'athlete-name').text)
                data.append(athletes.find('div',class_ = 'academy-name').text)
                data.append(soup.find('h3', {'class':'title-section text-center'}).text)

        for new in result.find_all('div',{'class':'category mt-4 mb-3'}):
            categories.append(new.get_text(strip=True))
    else:
        europ = [154, 232, 352, 490, 652, 849, 1077]
        for j in europ:
            url='https://www.ibjjfdb.com/ChampionshipResults/{}/PublicResults'.format(j)
            response = requests.get(url)
            soup = BeautifulSoup(response.text,"html.parser")
            result = soup.find('div', class_ = 'col-xs-12 col-md-6 col-athlete')

            for new in result.find_all('div', {'class':'list'}):
                for athletes in new.find_all('div', {'class':'athlete-item'}):
                    data.append(athletes.find('div',{"class": 'position-athlete'}).get_text(strip=True).replace("\r""\n"'                         ', ""))
                    data.append(athletes.find('p').get_text(strip=True).replace("\r""\n"'                         ', ""))
                    data.append(athletes.find('span').get_text(strip=True).replace("\r""\n"'                         ', ""))
                    data.append(soup.find_all('h2', {'class':'title'})[1].text.replace("\r\n"" ", ""))

            for new in result.find_all('h4',{'class':'subtitle'}):
                categories.append(new.get_text(strip=True).replace("\r""\n"'                         ', ""))
                

inner_size = 4
finaldata = [ data[i:i+inner_size] for i in range(0, len(data), inner_size) ]
dataf = pd.DataFrame(finaldata)
dataf.columns =['Place','Athlete','Team','Tournament']




# copying the colum PLACE of the dataf and excluding the first line of this one
newplace= dataf[['Place']].copy()
newplace2= newplace.iloc[1:]
# transform in a list
newplace3= dataf['Place'].tolist()

#transform places of athletes in 1 or -1 and deleting the first row
a = [-1 if i == '1' else 1 for i in newplace3]
del a[0]

index = 0
while len(listz)<len(a):
    for y in a:
        if y>=0:
            listz.append(categories[index])
        else:
            index = (index + 1) % len(categories)
            listz.append(categories[index])


#matching both dataframes
listz.insert(0, categories[0])

datafz = pd.DataFrame(listz)
datafz.columns =['Category']

d=pd.concat([dataf, datafz], axis=1)
d
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-957f5c1eef11> in <module>()
#      38                     data.append(athletes.find('p').get_text(strip=True).replace("\r""\n"'                         ', ""))
#      39                     data.append(athletes.find('span').get_text(strip=True).replace("\r""\n"'                         ', ""))
# ---> 40                     data.append(soup.find_all('h2', {'class':'title'})[1].text.replace("\r\n"" ", ""))
#      41
#      42             for new in result.find_all('h4',{'class':'subtitle'}):
#
# ~/anaconda3/lib/python3.6/site-packages/bs4/element.py in find_all(self, name, attrs, recursive, text, limit, **kwargs)
#    1311         if not recursive:
#    1312             generator = self.children
# -> 1313         return self._find_all(name, attrs, text, limit, generator, **kwargs)
#    1314     findAll = find_all       # BS3
#    1315     findChildren = find_all  # BS2
#
# ~/anaconda3/lib/python3.6/site-packages/bs4/element.py in _find_all(self, name, attrs, text, limit, generator, **kwargs)
#     554                 break
#     555             if i:
# --> 556                 found = strainer.search(i)
#     557                 if found:
#     558                     results.append(found)
#
# ~/anaconda3/lib/python3.6/site-packages/bs4/element.py in search(self, markup)
#    1702         elif isinstance(markup, Tag):
#    1703             if not self.text or self.name or self.attrs:
# -> 1704                 found = self.search_tag(markup)
#    1705         # If it's text, make sure the text matches.
#    1706         elif isinstance(markup, NavigableString) or \
#
# ~/anaconda3/lib/python3.6/site-packages/bs4/element.py in search_tag(self, markup_name, markup_attrs)
#    1658         if ((not self.name)
#    1659             or call_function_with_tag_data
# -> 1660             or (markup and self._matches(markup, self.name))
#    1661             or (not markup and self._matches(markup_name, self.name))):
#    1662             if call_function_with_tag_data:
#
# ~/anaconda3/lib/python3.6/site-packages/bs4/element.py in _matches(self, markup, match_against, already_tried)
#    1750
#    1751         if (hasattr(match_against, '__iter__')
# -> 1752             and not isinstance(match_against, str)):
#    1753             # We're asked to match against an iterable of items.
#    1754             # The markup must be match at least one item in the
#
# KeyboardInterrupt:

# %%
dataf
# Out:
#      Place                  Athlete                     Team  \
# 0        1          Ernesto Fonseca         Gracie Barcelona
# 1        2             Said Almoudi                  Behring
# 2        3        Alexander Taveira             F. Jiu-Jitsu
# 3        3    Joel Rosario da Costa    Gracie Barra Portugal
# 4        1             Pablo Piedra                  US Army
# 5        2   Jose Antonio Hernandez                  Behring
# 6        3            Geraldo Duvet            Gracie Geneve
# 7        3              Marki David         Master JJ France
# 8        1            Dejan Nicolic            Gracie Geneve
# 9        2          Javier Martinez         Gracie Barcelona
# 10       3             Julio Santos    Gracie Barra Portugal
# 11       3         Alexandre Soares             F. Jiu-Jitsu
# 12       1         Joao Paulo Silva             F. Jiu-Jitsu
# 13       2         Miguel Rodriguez                  Behring
# 14       3         Jefferson Santos             F. Jiu-Jitsu
# 15       3            David Cardoso             F. Jiu-Jitsu
# 16       1     Santiago Gomez Lopez                  Behring
# 17       2           Javier Beltran         Gracie Barcelona
# 18       3  Francisco Javier Garcia                  Behring
# 19       3         Paulo Branquinho    Gracie Barra Portugal
# 20       1          David Benakazou         Gracie Barcelona
# 21       2          Mauricio Santos                Pro Fight
# 22       3          Guilherme Alves    Gracie Barra Portugal
# 23       3          Bauer Christian     German National Team
# 24       1          Tiago Ventinhas    Gracie Barra Portugal
# 25       1            Chris Crossan   Gracie Barra Doncaster
# 26       2            Gozler Attila     German National Team
# 27       1               Asif Ahmad          Gracie Barra UK
# 28       1           Helio Perdigao         Gracie Barcelona
# 29       2              Mauro Ginja  Sandro Bala/Sergio Vita
# ...    ...                      ...                      ...
# 4608     2            Andre Almeida             Gracie Barra
# 4609     3             Gileno Souza                Nine Nine
# 4610     1            Henrique Lima             Checkmat BJJ
# 4611     2            Jose Everaldo                  Clan JJ
# 4612     3            Jorg Lothmann     BJJ Team Marshmallow
# 4613     3       Morgann Paraskevas         Yamasaki Academy
# 4614     1            Mariusz Linke   Gold Team Fighters USA
# 4615     2             Sergio Avila               De La Riva
# 4616     3    Regis Alexandre Silva           Gracie Humaita
# 4617     1       Andrea Scortegagna               Nova Uniao
# 4618     2            Gilles Arsene             Icon JJ Team
# 4619     3         Gianfranco Paoli   League Jiu Jistu Italy
# 4620     1      Joao Carlos Martins             Icon JJ Team
# 4621     1             Sergio Avila               De La Riva
# 4622     2       Andrea Scortegagna               Nova Uniao
# 4623     3            Andre Almeida             Gracie Barra
# 4624     3            Henrique Lima             Checkmat BJJ
# 4625     1           Marco Carneiro             Icon JJ Team
# 4626     1        Van Dick Oliveira               Joao Roque
# 4627     1               Andre Cruz                    Pejor
# 4628     2          Alison Henrique                    Jucao
# 4629     3          Marco Galzenati   League Jiu Jistu Italy
# 4630     3             John Hartley             Gracie Barra
# 4631     1             Kelly Rundle                 Alliance
# 4632     2              Cecil Burch                  Megaton
# 4633     1          Alison Henrique                    Jucao
# 4634     2             Kelly Rundle                 Alliance
# 4635     3        Van Dick Oliveira               Joao Roque
